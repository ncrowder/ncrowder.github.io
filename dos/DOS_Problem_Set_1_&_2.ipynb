# %% [markdown]
# <a href="https://colab.research.google.com/github/ncrowder/ncrowder.github.io/blob/main/dos/DOS_Problem_Set_1_%26_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Set 1

# %%
#1

# %%
code here

# %%
#2

# %%
code here

# %%
#etc etc etc

# %% [markdown]
# # Problem Set 2

# %%
#1a

# %%
code here

# %%
#1b

# %%
code here

# %%
#etc etc etc
