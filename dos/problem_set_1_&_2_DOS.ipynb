# %% [markdown]
# <a href="https://colab.research.google.com/github/ncrowder/ncrowder.github.io/blob/main/dos/problem_set_1_%26_2_DOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Set 1

# %%
#1

# %%
code

# %% [markdown]
# # Problem Set 2

# %%
#2
